# %% [markdown]
# <a href="https://colab.research.google.com/github/mahamapara/SQL/blob/master/trial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# orders query: ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
/*Just the query:

SELECT name, price
FROM customers
INNER JOIN orders
    ON customers.order_id = orders.id
WHERE order_date <= DATEADD(year, 10, SELECT MIN(order_date) FROM orders)
ORDER BY price DESC
*/



/*Attempt one with printing:

DECLARE @myAns varchar(100)
SET @myAns = ''

SELECT @myAns = name + ' ' + price
FROM customers
INNER JOIN orders
    ON customers.order_id = orders.id
WHERE order_date <= DATEADD(year, 10, SELECT MIN(order_date) FROM orders)
ORDER BY price DESC;

PRINT @myAns
*/


/* Attempt two with printing:*/
$this = "SELECT name, price
FROM customers
INNER JOIN orders
    ON customers.order_id = orders.id
WHERE order_date <= DATEADD(year, 10, SELECT MIN(order_date) FROM orders)
ORDER BY price DESC";

$ans = mysql_query($query) or die(mysql_error());

while($row = mysql_fetch_assoc($ans)){
    foreach($row as $cname => $cvalue){
        print "$cname: $cvalue\t";
    }
    print "\r\n";
}
